# %% [markdown]
# #### Google Colab Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

PROJECT_PATH = 'Colab Notebooks/CW_Folder_PG'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', PROJECT_PATH)

# %% [markdown]
# #### Setting Environment, Installing packages

# %%
LIB_PATH = f"{GOOGLE_DRIVE_PATH}/requirements.txt"
# !pip install -r "{LIB_PATH}"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 701.7 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### Import tools and functions

# %%
# %run "{GOOGLE_DRIVE_PATH}/Code/Tools.ipynb"
# %run "{GOOGLE_DRIVE_PATH}/Code/Models.ipynb"
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 164 ms (started: 2024-04-20 19:10:21 +00:00)

# %% [markdown]
# ### **Images**

# %% [markdown]
# #### SVM - HOG

# %%
# A function to randomly predict 4 pictures from test set
# MaskDetection(Path to test data, Type of model)

MaskDetection('test', 'SVM-HOG')
# Out:
# time: 704 ms (started: 2024-04-20 19:21:16 +00:00)

# %% [markdown]
# #### SVM - SIFT

# %%
# A function to randomly predict 4 pictures from test set
# MaskDetection(Path to test data, Type of model)
MaskDetection('test', 'SVM-SIFT')
# Out:
# time: 710 ms (started: 2024-04-20 19:21:17 +00:00)

# %% [markdown]
# #### Custom CNN

# %%
# A function to randomly predict 4 pictures from test set
# MaskDetection(Path to test data, Type of model)

MaskDetection('test', 'CustomCNN')
# Out:
# time: 1.05 s (started: 2024-04-20 19:21:18 +00:00)

# %% [markdown]
# #### Pretrained-CNN : ResNet50

# %%
# A function to randomly predict 4 pictures from test set
# MaskDetection(Path to test data, Type of model)

MaskDetection('test', 'ResNet50')
# Out:
# time: 5.15 s (started: 2024-04-20 19:21:19 +00:00)

# %% [markdown]
# #### Pretrained-CNN : MobileNet

# %%
# A function to randomly predict 4 pictures from test set
# MaskDetection(Path to test data, Type of model)

MaskDetection('test', 'MobileNet')
# Out:
# time: 3.21 s (started: 2024-04-20 19:21:24 +00:00)

# %% [markdown]
# #### Pretrained-CNN : VGG16

# %%
# A function to randomly predict 4 pictures from test set
# MaskDetection(Path to test data, Type of model)

MaskDetection('test', 'VGG16')
# Out:
# time: 3.57 s (started: 2024-04-20 19:21:27 +00:00)

# %% [markdown]
# #### Pretrained-CNN : EfficientNetB0

# %%
# A function to randomly predict 4 pictures from test set
# MaskDetection(Path to test data, Type of model)

MaskDetection('test', 'EfficientNet')
# Out:
# time: 6.14 s (started: 2024-04-20 19:21:31 +00:00)

# %% [markdown]
# ### **Video**

# %%
# A function to perform  face mask detection on video
# MaskDetectionVideo()

MaskDetectionVideo()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
